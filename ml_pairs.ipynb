# ['10866.0', '11156.0', '11287.0', '11439.0', '11770.0', '12052.0', '12132.0', '12183.0', '12394.0', '12511.0', '12909.0', '13119.0', '14496.0', '14699.0', '15229.0', '15624.0', '16096.0', '16600.0', '17232.0', '17742.0', '18331.0', '18542.0', '19350.0', '19713.0', '19860.0', '20079.0', '20087.0', '20220.0', '20984.0', '21434.0', '21856.0', '21979.0', '22461.0', '23034.0', '23237.0', '23421.0', '23691.0', '23878.0', '24141.0', '24328.0', '24563.0', '25128.0', '25304.0', '26323.0', '26497.0', '26817.0', '26833.0', '27596.0', '28513.0']
#
# Cluster 17:
# ['10153.0', '10233.0', '10276.0', '11092.0', '11949.0', '12036.0', '12343.0', '12431.0', '13370.0', '13637.0', '13856.0', '14613.0', '14728.0', '15034.0', '15325.0', '15456.0', '15536.0', '16256.0', '16360.0', '16571.0', '16803.0', '17013.0', '17128.0', '17478.0', '17523.0', '17750.0', '18016.0', '18032.0', '18163.0', '18358.0', '18649.0', '18729.0', '18905.0', '19131.0', '19238.0', '19596.0', '19772.0', '19879.0', '20052.0', '20431.0', '20626.0', '20976.0', '21135.0', '21143.0', '22525.0', '22779.0', '22795.0', '23675.0', '23915.0', '23990.0', '24176.0', '24619.0', '24715.0', '24758.0', '25101.0', '25531.0', '25574.0', '25654.0', '26227.0', '26286.0', '26294.0', '26307.0', '26518.0', '26526.0', '26673.0', '26761.0', '26876.0', '27043.0', '27350.0', '27406.0', '27422.0', '28222.0']
#
# Cluster 18:
# ['12001.0', '13987.0', '15042.0', '21653.0', '28134.0']
#
# Cluster 19:
# ['14218.0', '14875.0', '17224.0', '17865.0', '18980.0', '19406.0', '20116.0', '20407.0', '21557.0', '21995.0', '22357.0', '22816.0', '22939.0', '25021.0', '25398.0', '26382.0', '26438.0', '26913.0', '27086.0', '27166.0', '27342.0', '27393.0', '27705.0', '28003.0', '28126.0', '28150.0', '28185.0', '28265.0', '86239.0']

# %%
from pairs_formation import compute_pairwise_ssd, pair_matching, get_stock

# %%
pairs_ml = []

for cluster_id, members in clusters.groupby(clusters):
    stocks = members.index.values
    if len(stocks) < 2:
        continue

    sub = X.query("index.isin(@stocks)").T

    # Compute SSDs 
    print("Computing pairwise SSD")
    ssd_df = compute_pairwise_ssd(sub)

    # Match into pairs
    print("Matching into pairs")
    matched_pairs = pair_matching(ssd_df, crsp_data, max_pairs=10000)
    matched_pairs = matched_pairs.sort_values('ssd').reset_index(drop=True)
    matched_pairs_named = get_stock(matched_pairs)

    print(f"Total pairs formed: {len(matched_pairs_named)} for cluster ID: {cluster_id} with {len(stocks)} stocks")
    print(matched_pairs_named)
    matched_pairs_named.to_csv("ml_pairs/total_matched_pairs/matched_pairs_1963-01-01_1963-12-31_cluster_"+str(cluster_id)+".csv", index=False)
# Out:
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 11 for cluster ID: 0 with 22 stocks
#     permno_1  permno_2       ssd                     comnam_1  permco_1  \
# 0      18948     53023  0.553154  ROCKWELL INTERNATIONAL CORP     21524
# 1      18606     19414  0.564067                    AVCO CORP     22861
# 2      14955     17435  0.680026     CHIQUITA BRANDS INTL INC     22568
# 3      10727     20327  0.761742             BAYUK CIGARS INC     22219
# 4      19027     26569  0.850450                CELANESE CORP     22888
# 5      15341     15798  1.009400    WESTINGHOUSE AIR BRAKE CO     22600
# 6      10671     23296  1.199569   BALDWIN LIMA HAMILTON CORP     22215
# 7      14488     21864  2.148806           SOUTH P R SUGAR CO     22528
# 8      15544     26331  2.432718                 MCCRORY CORP     22614
# 9      17101     25486  4.137755                WILCOX OIL CO     22746
# 10     12554     22904  4.585677  INTERNATIONAL RYS CENT AMER     22363
#
#    ticker_1 naics_1                      comnam_2  permco_2 ticker_2 naics_2
# 0       ROK    <NA>  MERRITT CHAPMAN & SCOTT CORP      2874     MERR    <NA>
# 1        AV    <NA>                  GETTY OIL CO     22919      GET    <NA>
# 2       CQB    <NA>             EVANS PRODUCTS CO     22778      EVY    <NA>
# 3       BYK    <NA>          NATIONAL CASTINGS CO     22991      NML    <NA>
# 4        CZ    <NA>                 LYKES CORP DE     23415       LY    <NA>
# 5        WK    <NA>                   FAWICK CORP     22633      FAW    <NA>
# 6         B    <NA>                  BEAUNIT CORP     23203      BEM    <NA>
# 7       PSU    <NA>    BRANIFF INTERNATIONAL CORP     23107      BNF    <NA>
# 8        MS    <NA>       ALLIED PRODUCTS CORP DE     20050      ADP    <NA>
# 9       WXC    <NA>    NEW YORK SHIPBUILDING CORP     23338      NSB    <NA>
# 10      IRC    <NA>                MONON RAILROAD     23176      MON    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 29 for cluster ID: 1 with 58 stocks
#     permno_1  permno_2       ssd                         comnam_1  permco_1  \
# 0      18569     27270  0.213365                    FIRESTONE INC     22857
# 1      17689     25427  0.257825         ANACONDA WIRE & CABLE CO     22796
# 2      19289     23288  0.292007                       MESTEK INC     21195
# 3      27529     27991  0.324958                 DUBOIS CHEMS INC     23483
# 4      16707     16731  0.334181                    MANVILLE CORP     21151
# 5      22242     26374  0.360802  EMERSON RADIO & PHONOGRAPH CORP     23129
# 6      10532     18390  0.367936            ARNOLD CONSTABLE CORP     22199
# 7      26200     26956  0.401542  UNITED STATES BORAX & CHEM CORP     23392
# 8      22568     24512  0.434837                        GOULD INC     23150
# 9      24205     25769  0.455208               NEXTERA ENERGY INC     20684
# 10     13434     14154  0.456920              NEW YORK CENT RR CO     22436
# 11     21901     23050  0.476536                ROYAL MC BEE CORP     23110
# 12     11033     27190  0.493132              CALUMET & HECLA INC     22243
# 13     16651     22330  0.500857                BECOR WESTERN INC     22708
# 14     19617     21733  0.525222         TRANS WORLD AIRLINES INC     22934
# 15     10188     19684  0.525947             AMBAC INDUSTRIES INC     22170
# 16     20597     26403  0.538870                     WHITE S S CO     23012
# 17     10524     21813  0.567979                      ARMOUR & CO     22198
# 18     19561     26980  0.597889                        BOEING CO     20315
# 19     12044     16512  0.683458                      CULBRO CORP     20542
# 20     23472     27051  0.901666                      RONSON CORP      7946
# 21     17400     27748  0.942314                ALLEGHANY CORP MD     22775
# 22     24897     27123  1.025190         FAIRCHILD INDUSTRIES INC     23300
# 23     22488     24651  1.052701                     ADMIRAL CORP     23147
# 24     17734     24993  1.078089              GENERAL BRONZE CORP     22800
# 25     26008     26251  1.184383     PACIFIC CEM & AGGREGATES INC     23375
# 26     27430     28097  1.330321          COOPER TIRE & RUBBER CO     20518
# 27     16643     27916  1.828911                 BOSTON & ME CORP     22707
# 28     19203     28169  3.860814             DOUGLAS AIRCRAFT INC     22902
#
#    ticker_1 naics_1                       comnam_2  permco_2 ticker_2 naics_2
# 0       FIR    <NA>                 ARMTEK CORP DE     23465      ARM    <NA>
# 1       AWC    <NA>                OXFORD PAPER CO     23333      OXP    <NA>
# 2       MCC  336391                   WELBILT CORP      4894     WELB    <NA>
# 3        DU    <NA>     PINNACLE WEST CAPITAL CORP     21409      PNW  221118
# 4       MAN    <NA>         LEHIGH PORTLAND CEM CO     22713      LPT    <NA>
# 5       ERP    <NA>             CARTER WALLACE INC     20401      CAR    <NA>
# 6       ACT    <NA>           NEISNER BROTHERS INC     22846      NEB    <NA>
# 7       UBX    <NA>          WALLACE & TIERNAN INC     23441      WLT    <NA>
# 8       GLD    <NA>                GLEN ALDEN CORP     23275       GA    <NA>
# 9       NEE  221118                KERR MCGEE CORP     21049      KMG  211111
# 10       CN    <NA>      READING ENTERTAINMENT INC      6659     RDGE    <NA>
# 11      RMB    <NA>            REEVES BROTHERS INC     23185      RVS    <NA>
# 12      CAH    <NA>  AMERICAN HOSPITAL SUPPLY CORP     23459      AHS    <NA>
# 13      BCW    <NA>        NATIONAL SUGAR REFNG CO     23136      NSU    <NA>
# 14      TWA    <NA>            BEECH AIRCRAFT CORP     23099      BCX    <NA>
# 15       AB    <NA>                   CLEVITE CORP     22941      CGH    <NA>
# 16      WDM    <NA>                 DISNEY WALT CO     20587      DIS  713110
# 17       AM    <NA>                   RHEEM MFG CO     23104      RHE    <NA>
# 18       BA  336411           RYAN AERONAUTICAL CO     23444      RYC    <NA>
# 19      CBO    <NA>         MACANDREWS & FORBES CO     22697      MAF    <NA>
# 20     RONC  325110                      A M P INC     23449      AMP    <NA>
# 21        Y    <NA>     FLORIDA EAST COAST IND INC     20738      FLA  482112
# 22      FEN    <NA>                 MARQUARDT CORP     23454      MRQ    <NA>
# 23      ADL    <NA>                   STANRAY CORP     23286      SRY    <NA>
# 24      GLZ    <NA>      JEFFERSON LAKE SULPHUR CO     23307      JEF    <NA>
# 25      PAG    <NA>            GENERAL CONTROLS CO     23397      GCC    <NA>
# 26      CTB  326211                    MCNEIL CORP     23518      MME    <NA>
# 27      BMR    <NA>                      GINN & CO     23506      GNN    <NA>
# 28        D    <NA>  FAIRCHILD CAMERA & INSTR CORP     23523      FCI    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 49 for cluster ID: 2 with 98 stocks
#     permno_1  permno_2       ssd                          comnam_1  permco_1  \
# 0      22517     24221  0.128095                        P P L CORP     21376
# 1      18411     24360  0.133432                       SOUTHERN CO     21640
# 2      10401     21194  0.134815                      A T & T CORP     20103
# 3      24301     26606  0.155855           ATLANTIC ENERGY INC N J     20228
# 4      25793     28046  0.167992                   HARSHAW CHEM CO     23360
# 5      18999     19553  0.171026        COMBUSTION ENGINEERING INC     22886
# 6      12271     27449  0.177126                HELME PRODUCTS INC     22344
# 4       HCM    <NA>           EBASCO INDUSTRIES INC     23513      EBS    <NA>
# 5       CSP    <NA>                      AMOCO CORP     20191       AN    <NA>
# 6       HPI    <NA>                 GIANT GROUP LTD     20815      GPO    <NA>
# 7        PD  331411             BOND INDUSTRIES INC       584     BNDN    <NA>
# 8        AN    <NA>              CARLING OKEEFE LTD     23189      CKB    <NA>
# 9        KN    <NA>             ANCHOR HOCKING CORP     22759      ARH    <NA>
# 10      ETN  541611                    P G & E CORP     21356      PCG  221118
# 11      BOR    <NA>  WALKER HIRAM GOODERHAM & WORTS     22960      HIR    <NA>
# 12        A    <NA>             CAREY PHILIP MFG CO     23264      CAY    <NA>
# 13      PPG  325510                     MEDUSA CORP     21987      MPD    <NA>
# 14       MQ    <NA>                WHITE MOTOR CORP     22914       WH    <NA>
# 15      OTU    <NA>        AMERICAN WATER WORKS INC     20104      AWK    <NA>
# 16      ASF    <NA>         FEDERAL PAPER BOARD INC     20696      FBO    <NA>
# 17      CIS    <NA>                  CONOCOPHILLIPS     21401      COP  213112
# 18       MM    <NA>      BELL INTERCONTINENTAL CORP     23086      BLL    <NA>
# 19       AR    <NA>               PENNEY J C CO INC     21375      JCP  452111
# 20      NTS    <NA>                      PORTEC INC     21429      POR    <NA>
# 21      IPL    <NA>              PEPCO HOLDINGS INC     21432      POM  221111
# 22      SGP    <NA>                   DE VILBISS CO     23182      DEV    <NA>
# 23      AAL  481111           ANDERSON CLAYTON & CO     23131      AYL    <NA>
# 24      CGG    <NA>                    CARRIER CORP     23149      CRR    <NA>
# 25      IKN    <NA>                    GARRETT CORP     23251      GAR    <NA>
# 26      ANV    <NA>                    CONECTIV INC     20568      CIV    <NA>
# 27      NRB    <NA>     UNITED MERCHANTS & MFRS INC     21824      UMM    <NA>
# 28      MGR    <NA>                 SUNBEAM CORP DE     23252      SMB    <NA>
# 29      LCE    <NA>              ALLIED STORES CORP     22766      ALS    <NA>
# 30      CNP  221210                DIVCO WAYNE CORP     23212      DCO    <NA>
# 31      MEA    <NA>         SHAMROCK OIL & GAS CORP     23125      SHM    <NA>
# 32      TNW    <NA>            INDIANA GENERAL CORP     23486      IGC    <NA>
# 33      RVB    <NA>                     GENESCO INC     20805      GCO  458210
# 34      NOM    <NA>                    CAMPBELLS CO     20384      CPB  311412
# 35       SW    <NA>                     TENNECO INC     21729      TEN    <NA>
# 36      SUO    <NA>                TIDEWATER OIL CO     22668       TV    <NA>
# 37      FMC  325180             EASTERN ENTERPRISES     20623      EFU    <NA>
# 38      AKD    <NA>                BUFFALO FORGE CO     23087      BFC    <NA>
# 39      CNR    <NA>     HOUSEHOLD INTERNATIONAL INC     20938       HI    <NA>
# 40      HWM  331318           NORRIS INDUSTRIES INC     23477      NRI    <NA>
# 41      CRC    <NA>                     RAYTHEON CO     21492      RTN  334511
# 42       RL    <NA>                       PASCO INC     23478      PAS    <NA>
# 43        M    <NA>  NEW YORK CHICAGO & ST LOUIS RR     22437      NKP    <NA>
# 44      COG    <NA>       GENERAL CONTRACT FIN CORP     23419      GCF    <NA>
# 45      AHD    <NA>                  GRACE W R & CO     20840      GRA    <NA>
# 46     HOWD    <NA>       CONTINENTAL AIR LINES INC     23504      CAL    <NA>
# 47       AJ    <NA>                LEHIGH GROUP INC     21074      LEI    <NA>
# 48      SPT    <NA>                 DINERS CLUB INC      1316     DINR    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed:
# 10       PU    <NA>           GENERAL PORTLAND INC     23213      GPT    <NA>
# 11      SGP  325412                   MARQUETTE CO     23318      MQC    <NA>
# 12      MCK    <NA>        STANDARD PACKAGING CORP     23408      SPK    <NA>
# 13      BDC    <NA>         S P S TECHNOLOGIES INC     21547       ST    <NA>
# 14      HLL    <NA>                      UPJOHN CO     21843      UPJ    <NA>
# 15      SSH    <NA>             CESSNA AIRCRAFT CO     23358      CEA    <NA>
# 16      REV    <NA>                        H P INC     20908      HPQ  334111
# 17      RLM    <NA>               LEAR SIEGLER INC     23410      LSI    <NA>
# 18      COT    <NA>       FAIRBANKS MORSE & CO INC     22311      FKM    <NA>
# 19       KT    <NA>  ELGIN NATIONAL INDUSTRIES INC     23201      ENW    <NA>
# 20      CXT  332912         CHOCK FULL O NUTS CORP     20443      CHF    <NA>
# 21      ABA    <NA>              DIANA STORES CORP     23245      DIN    <NA>
# 22     CWLE    <NA>                      C C X INC     20355      CCX    <NA>
# 23      UVT    <NA>                   MAYS J W INC      7337     MAYS  531312
# 24       CV    <NA>   AMERICAN RESEARCH & DEV CORP     23501      ARD    <NA>
# 25      CDE    <NA>                  AMPHENOL CORP     23386      ABE    <NA>
# 26      GRX    <NA>                  MACMILLAN INC     23447      MLL    <NA>
# 27      GRH    <NA>       CORDANT TECHNOLOGIES INC     21228      CDD    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 23 for cluster ID: 5 with 46 stocks
#     permno_1  permno_2       ssd                    comnam_1  permco_1  \
# 0      17451     17654  0.192149                LINK BELT CO     22780
# 1      14082     15966  0.268634                 PURE OIL CO     22496
# 2      25152     27940  0.281797            COSDEN PETE CORP     23314
# 3      18825     21389  0.288893  AMERICAN CHAIN & CABLE INC     22876
# 4      22947     23536  0.359356                CINERGY CORP     20449
# 5      14883     24379  0.366694             UNION CAMP CORP     21805
# 6      10030     20546  0.392676                   ABEX CORP     22160
# 7      10006     23341  0.405145        A C F INDUSTRIES INC     22156
# 8      21338     23579  0.440841          FEDERAL MOGUL CORP     20694
# 9      11463     11746  0.453104     CONTINENTAL MOTORS CORP     22280
# 10     23819     24707  0.454842              HALLIBURTON CO     20868
# 11     22760     25806  0.467005                MOHASCO CORP     23165
# 12     15747     21821  0.562766              INTERLAKE CORP     20988
# 13     20482     20837  0.575487         ABBOTT LABORATORIES     20017
# 14     11850     21549  0.684678            EXXON MOBIL CORP     20678
# 15     21274     25419  0.803493                GRUMMAN CORP     20855
# 16     23042     26454  0.806058     EMPIRE DISTRICT ELEC CO     20646
# 17     12386     24635  1.039266                   HUPP CORP     22353
# 18     13936     21602  1.040433                  P V H CORP     21402
# 19     10196     24336  1.059048      AMERICAN & FGN PWR INC     22171
# 20     10479     24686  1.178750                 AMSTAR CORP     22194
# 21     19174     22066  2.090195           GENERAL HOST CORP     20795
# 22     14090     18243  3.552669                  R C A CORP     22497
#
#    ticker_1 naics_1                         comnam_2  permco_2 ticker_2  \
# 0       LKB    <NA>                ROCKWELL STD CORP     22794      RKS
# 1        PY    <NA>                       MOBIL CORP     21211      MOB
# 2       CPM    <NA>               TEXAS EASTERN CORP     23508      TET
# 3       ACN    <NA>           PITTSBURGH FORGINGS CO     23063      PFG
# 4       CIN  221119           W E C ENERGY GROUP INC     21931      WEC
# 5       UCC    <NA>           R G S ENERGY GROUP INC     21520      RGS
# 6       ABK    <NA>             ALLEN INDUSTRIES INC     23008      ANL
# 7       ACF    <NA>             AMERICAN CYANAMID CO     20076      ACY
# 8       FMO    <NA>                      TEXTRON INC     21743      TXT
# 9       CMR    <NA>                        E S B INC     22301      ESB
# 10      HAL  213112                  CONE MILLS CORP     23289      COE
# 11      MOH    <NA>                RIEGEL PAPER CORP     23361      RGP
# 12       IK    <NA>      CONSOLIDATED NATURAL GAS CO     20502      CNG
# 13      ABT  325412                     RAYONIER INC     23029      RNR
# 14      XOM  211120                       A V C CORP     23079      AVC
# 15       GQ    <NA>                   WHIRLPOOL CORP     21916      WHR
# 16      EDE  221122                  SUNDSTRAND CORP     21688      SNS
# 17        H    <NA>                KAISERTECH LTD DE     23285      KLU
# 18      PVH  315250                DECCA RECORDS INC     23084      DKA
# 19       AF    <NA>                      SCOVILL INC     23265      SCO
# 20      ASR    <NA>           KING SEELEY THERMOS CO     23287      KST
# 21       GH    <NA>  NATIONAL SERVICE INDUSTRIES INC     21262      NSI
# 22      RCA    <NA>              CHECKER MOTORS CORP     22838      CHC
#
#    naics_2
# 0     <NA>
# 1     <NA>
# 2     <NA>
# 3     <NA>
# 4   221118
# 5     <NA>
# 6     <NA>
# 7     <NA>
# 8   336411
# 9     <NA>
# 10    <NA>
# 11    <NA>
# 12    <NA>
# 13    <NA>
# 14    <NA>
# 15  335220
# 16    <NA>
# 17    <NA>
# 18    <NA>
# 19    <NA>
# 20    <NA>
# 21    <NA>
# 22    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 32 for cluster ID: 6 with 64 stocks
#     permno_1  permno_2       ssd                          comnam_1  permco_1  \
# 0      26622     26892  0.187091            CHAMPION SPARK PLUG CO     23418
# 1      15819     21418  0.188155             CONTINENTAL BAKING CO     22635
# 2      11308     13661  0.207274                      COCA COLA CO     20468
# 3      13696     25291  0.212650      PACIFIC TELEPHONE & TELEG CO     22463
# 4      16109     18550  0.232298                GENERAL FOODS CORP     22660
# 5      14533     25910  0.248740               STANDARD BRANDS INC     22534
# 6      13610     23632  0.257403                         OLIN CORP     21329
# 7      15659     22840  0.267906                UNION CARBIDE CORP     21806
# 8      14891     22007  0.286274                       UNOCAL CORP     21842
# 9      10735     24846  0.306620         BEECH NUT LIFE SAVERS INC     22220
# 10     15368     18446  0.311556                        C B S CORP     21912
# 11     17910     25849  0.312865              SURVEYOR FUND INC DE     22815
# 12     12730     12976  0.330903                         KRAFT INC     22378
# 13     10823     18710  0.345827               KEYSPAN ENERGY CORP     20338
# 14     17144     18382  0.368432                 GENERAL MILLS INC     20798
# 15     18681     22496  0.379489                         T R W INC     21705
# 16     16555     25339  0.403146                    UNIVERSAL CORP     21838
# 17     10487     11981  0.421168             AMSTED INDUSTRIES INC     22195
# 18     16678     17953  0.444455                         KROGER CO     21068
# 19     12829     22293  0.457765            LEHN & FINK PRODS CORP     22384
# 20     21266     22437  0.513267           MC KESSON & ROBBINS INC     23057
# 21     14322     21928  0.521406                SEARS ROEBUCK & CO     21592
# 22     12458     17347  0.526537                       RYERSON INC     20978
# 23     27385     27510  0.540185       ORANGE & ROCKLAND UTILS INC     21336
# 24     19668     25515  0.568910                        ALDENS INC     22939
# 25     22752     27852  0.637063                MERCK & CO INC NEW     21188
# 26     22234     26550  0.661289                     PENNWALT CORP     23128
# 27     20458     22429  0.949267                        ATLAS CORP     20231
# 28     10647     17726  1.038333           AUSTIN NICHOLS & CO INC     22211
# 29     12124     28206  1.200429               GIMBEL BROTHERS INC     22329
# 30     12466     27983  1.634798  INSPIRATION CONSOLIDATED CPPR CO     22358
# 31     22306     24766  1.732153                        R A C CORP     23133
#
#    ticker_1 naics_1                         comnam_2  permco_2 ticker_2  \
# 0       CHM    <NA>                    FOOD MART INC     23433      FMR
# 1        CI    <NA>        NEWPORT NEWS SHIPBUILDING     23065      NND
# 2        KO  311930               OWENS ILLINOIS INC     22462       OI
# 3       PAC    <NA>          GENERAL BANCSHARES CORP     23325      GBS
# 4        GF    <NA>  FEDERATED DEPARTMENT STORES INC     22856      FDS
# 5        SB    <NA>               GERBER PRODUCTS CO     20811      GEB
# 6       OLN  325180         HEYDEN NEWPORT CHEM CORP     23223      HDN
# 7        UK    <NA>              HILLSHIRE BRANDS CO     21566      HSH
# 8       UCL  211111                GARDNER DENVER CO     23115      GDC
# 9       BLS    <NA>              AMERICAN OPTICAL CO     23295      AOC
# 10      CBS    <NA>               CLARK EQUIPMENT CO     20460      CKL
# 11      SFI    <NA>                        RANCO INC     23365      RNI
# 12      KRA    <NA>                MACY R H & CO INC     22397       MZ
# 13      KSE    <NA>          CARRIERS & GENERAL CORP     22869      CGR
# 14      GIS  311999                   PHARMACIA CORP     21214      PHA
# 15      TRW    <NA>            FLORIDA PROGRESS CORP     20739      FPC
# 16      UVV  424590              DREWRYS LTD USA INC     23327      DRE
# 17       AD    <NA>             FREEPORT MINERALS CO     22321       FT
# 18       KR  445110                      BEATRICE CO     22818      BRY
# 19      LNP    <NA>                      CORNING INC     20523      GLW
# 20      MCK    <NA>             C H ENERGY GROUP INC     20416      CHG
# 21        S  452110                      IDACORP INC     20965      IDA
# 22      RYI  331221            MARTIN PROCESSING INC     22770      MPI
# 23      ORU    <NA>     COCA COLA BOTTLING CO NY INC     23482      KNY
# 24      AUD    <NA>                       G A C CORP     23340      GAC
# 25      MRK  325412                  FACTOR MAX & CO     23503      FAC
# 26      PSM    <NA>         FIRST INTERSTATE BANCORP     20720        I
# 27       AZ    <NA>                   WARD FOODS INC     23144       WD
# 28      ANO    <NA>               CROWN HOLDINGS INC     20537      CCK
# 29     GMBL    <NA>                  VONS GROCERY CO     23527      VON
# 30       IC    <NA>              XEROX HOLDINGS CORP     21945      XRX
# 31       RA    <NA>            NORTHROP GRUMMAN CORP     21303      NOC
#
#    naics_2
# 0     <NA>
# 1     <NA>
# 2     <NA>
# 3     <NA>
# 4     <NA>
# 5     <NA>
# 6     <NA>
# 7   311811
# 8     <NA>
# 9     <NA>
# 10    <NA>
# 11    <NA>
# 12    <NA>
# 13    <NA>
# 14    <NA>
# 15    <NA>
# 16    <NA>
# 17    <NA>
# 18    <NA>
# 19  327212
# 20  221111
# 21  221118
# 22    <NA>
# 23    <NA>
# 24    <NA>
# 25    <NA>
# 26    <NA>
# 27    <NA>
# 28  332431
# 29    <NA>
# 30  334118
# 31  334511
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 7 for cluster ID: 7 with 14 stocks
#    permno_1  permno_2       ssd                  comnam_1  permco_1 ticker_1  \
# 0     12319     25478  0.348160       HOMESTAKE MINING CO     20926       HM
# 1     22912     24416  0.670554   NATIONAL CITY LINES INC      3150     NCLI
# 2     24950     26729  0.683821     STIX BAER & FULLER CO     23303      SBF
# 3     18040     20490  1.164365          UNITED CARBON CO     22824      UCB
# 4     22832     25814  2.047881   CHAMPLIN OIL & REFNG CO     23172      CHI
# 5     11690     23800  3.452720            DOME MINES LTD     22298       DM
# 6     12220     24344  3.612935  GULF MOBILE & OHIO RR CO     22339      GFO
#
#   naics_1                      comnam_2  permco_2 ticker_2 naics_2
# 0    <NA>   CAMPBELL RED LAKE MINES LTD     23337      CRK    <NA>
# 1    <NA>   IOWA ILLINOIS GAS & ELEC CO     21002      IWG    <NA>
# 2    <NA>        MCDONNELL DOUGLAS CORP     21178       MD    <NA>
# 3    <NA>     FIFTH AVE COACH LINES INC     23004      FCL    <NA>
# 4    <NA>                  FENESTRA INC     23362      FNT    <NA>
# 5    <NA>             GAMBLE SKOGMO INC     23238      GSK    <NA>
# 6    <NA>  DELTEC INTERNATIONAL LTD ENG     23266      DTL    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 21 for cluster ID: 8 with 42 stocks
#     permno_1  permno_2       ssd                     comnam_1  permco_1  \
# 0      12140     26219  0.251564                GOODRICH CORP     20833
# 1      24803     27318  0.274873        WINN DIXIE STORES INC     21926
# 2      19190     21346  0.275666                 CHEMWAY CORP     22901
# 3      16424     27174  0.277144                  GILLETTE CO     20818
# 4      12298     19537  0.290173                   HERTZ CORP     22345
# 5      18841     28089  0.328186                 BLAW KNOX CO     22878
# 6      11826     19510  0.348349        ENDICOTT JOHNSON CORP     22306
# 7      16686     22701  0.378936                 MC CALL CORP     22709
# 8      13557     20589  0.418355  NORTH AMERICAN PHILIPS CORP     22449
# 9      13901     17291  0.425888             ALTRIA GROUP INC     21398
# 10     27211     27879  0.454868           SUBURBAN COMPANIES     23461
# 11     12669     28257  0.490542             KAYSER ROTH CORP     22372
# 12     11068     15560  0.572953                  CASE J I CO     22244
# 13     25873     27713  0.574233                AMERIFIN CORP     23368
# 14     19019     27537  0.693943          NATIONAL STEEL CORP     21257
# 15     17072     24598  0.708235        INTERSTATE STORES INC     22743
# 16     25582     27000  0.853193    L3HARRIS TECHNOLOGIES INC     20883
# 17     18702     28118  1.067811     ANCORP NATIONAL SVCS INC       267
# 18     25697     28230  1.162364      BECKMAN INSTRUMENTS INC     23354
# 19     11017     20693  1.799307         CALLAHAN MINING CORP     20379
# 20     27297     27836  4.249546      FIRST CHARTER FINL CORP     23468
#
#    ticker_1 naics_1                       comnam_2  permco_2 ticker_2 naics_2
# 0        GR  336414           WAGNER ELEC CORP OLD     23393      WEC    <NA>
# 1       WIN  445120   NORTHWESTERN STEEL & WIRE CO     23469      NSW    <NA>
# 2       CMY    <NA>                  FOOD FAIR INC     23060      FFS    <NA>
# 3         G  332211             JONATHAN LOGAN INC     23458      JOL    <NA>
# 4       HRZ    <NA>                     N C R CORP     21241      NCR    <NA>
# 5        BK    <NA>       MARTIN MARIETTA ALUM INC     23517      MMA    <NA>
# 6       EJN    <NA>                NEWBERRY J J CO     22928      JJN    <NA>
# 7       MLL    <NA>                  EVERSHARP INC     23161      EVR    <NA>
# 8       NPH    <NA>                   CYCLOPS CORP     23011      CYL    <NA>
# 9        MO  312230             SAFEWAY STORES INC     22765       SA    <NA>
# 10      SUB    <NA>         HELENE CURTIS INDS INC     20901       HC    <NA>
# 11      KYR    <NA>                  SWINGLINE INC     23531      SWL    <NA>
# 12       JI    <NA>                RADIOSHACK CORP     21711      RSH  443142
# 13      AFN    <NA>     APPLIED BIOSYSTEMS INC DEL     21387      ABI  334516
# 14       NS    <NA>    HOLT RINEHART & WINSTON INC     23485      HRW    <NA>
# 15      ISD    <NA>     STANDARD KOLLSMAN INDS INC     23281      SKO    <NA>
# 16      LHX  334511             IMPERIAL CORP AMER     20971      ICA    <NA>
# 17     ANCP    <NA>           NACCO INDUSTRIES INC     21247       NC  335210
# 18      BEC    <NA>                  APCO OIL CORP     23529      AOL    <NA>
# 19      CMN    <NA>  SUNSHINE MINING & REFINING CO     21689      SSC    <NA>
# 20      FCF    <NA>              BOBBIE BROOKS INC      5297     BBKS    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 1 for cluster ID: 9 with 3 stocks
#    permno_1  permno_2       ssd        comnam_1  permco_1 ticker_1 naics_1  \
# 0     15253     23122  1.562891  WARD INDS CORP     22594      WIC    <NA>
#
#                       comnam_2  permco_2 ticker_2 naics_2
# 0  GRAYSON ROBINSON STORES INC     23190      GRB    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 14 for cluster ID: 10 with 29 stocks
#     permno_1  permno_2       ssd                     comnam_1  permco_1  \
# 0      23149     25611  0.579365       UNITED GREENFIELD CORP     23193
# 1      19721     22648  0.679168                    VIAD CORP     20851
# 2      22082     22269  0.904498               PANENERGY CORP     21362
# 3      25048     27609  0.927017                 FILTROL CORP     23309
# 4      15165     24213  1.151948  VIRGINIA CAROLINA CHEM CORP     22587
# 5      16053     27078  1.312102                 INSILCO CORP     22655
# 6      20298     26120  1.399376      TEXAS GULF PRODUCING CO     22988
# 7      10698     22664  1.402552              BARBER OIL CORP     22216
# 8      22189     26112  1.563987        NATIONAL AIRLINES INC     23124
# 9      17582     23333  1.829874       BOHN ALUM & BRASS CORP     22789
# 10     23261     24934  2.094101              BABBITT B T INC     23202
# 11     15712     25662  2.374844        COLLINS & AIKMAN CORP     22628
# 12     13848     14779  3.904357         PEORIA & EASTN RY CO     22476
# 13     14306     16782  5.087887        FUQUA ENTERPRISES INC      5519
#
#    ticker_1 naics_1                    comnam_2  permco_2 ticker_2 naics_2
# 0       UDG    <NA>   STORER COMMUNICATIONS INC     23347      SCI    <NA>
# 1       VVI  561499            DOCTOR PEPPER CO     23156      DOC    <NA>
# 2       PEL    <NA>       WESTERN AIR LINES INC     23130      WAL    <NA>
# 3       FLT    <NA>        HOOVER UNIVERSAL INC     23490      HVU    <NA>
# 4        VC    <NA>                 MCCORD CORP     23263      MCR    <NA>
# 5       INR    <NA>       KELLER INDUSTRIES INC     23450      KEL    <NA>
# 6        TR    <NA>  GENERAL AMERICAN OIL CO TX     23385      GAO    <NA>
# 7       BBO    <NA>         ROHN INDUSTRIES INC      5625     ROHN    <NA>
# 8       NAL    <NA>         DELTA AIR LINES INC     20569      DAL  481111
# 9       BHL    <NA>                UDYLITE CORP     23205      UYT    <NA>
# 10      BAB    <NA>       NATIONAL GENERAL CORP     23302      NGC    <NA>
# 11       CK    <NA>                  AKZONA INC     23350      AXO    <NA>
# 12      PER    <NA>     TEXAS PAC COAL & OIL CO     22553       TS    <NA>
# 13      FQE    <NA>     CHICKASHA COTTON OIL CO     22717      CIK    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 8 for cluster ID: 11 with 17 stocks
#    permno_1  permno_2       ssd                    comnam_1  permco_1  \
# 0     19852     28011  0.494727              SMITH A O CORP     21625
# 1     15448     18112  0.666936             WILSON & CO INC     22607
# 2     21936     21987  0.689579                  PFIZER INC     21394
# 3     10268     15202  1.012505  AMERICAN CONSUMER INDS INC     22178
# 4     11113     20474  1.098762               CHADBOURN INC     22249
# 5     17718     20888  1.485652                  BULLARD CO     22798
# 6     18489     19756  1.503033          PARMELEE TRANSN CO     22851
# 7     10890     14824  3.153745                 UNISYS CORP     21814
#
#   ticker_1 naics_1                  comnam_2  permco_2 ticker_2 naics_2
# 0      SMC    <NA>       PACKAGING CORP AMER     23511      PKG    <NA>
# 1      WIL    <NA>         FOSTER WHEELER AG     20757     FWLT  551112
# 2      PFE  325412      M S L INDUSTRIES INC     23113      MSL    <NA>
# 3     ACON    <NA>       VULCAN MATERIALS CO     21876      VMC  212313
# 4      CGI    <NA>                S C M CORP     23003      SCM    <NA>
# 5      BLD    <NA>  YOUNGSTOWN STEEL DOOR CO     23032      YSD    <NA>
# 6      PTE    <NA>    LIBBY MC NEILL & LIBBY     22947       LJ    <NA>
# 7      UIS  541512          TRANS UNION CORP     22556       TU    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 47 for cluster ID: 12 with 94 stocks
#     permno_1  permno_2       ssd                         comnam_1  permco_1  \
# 0      16870     20853  0.112137              PACIFIC ENTERPRISES     21355
# 1      23026     25590  0.129483                 FIRSTENERGY CORP     21326
# 2      10137     25072  0.149030             ALLEGHENY ENERGY INC     20045
# 3      11404     23229  0.149214          CONSOLIDATED EDISON INC     20499
# 4      11754     17849  0.150723                 EASTMAN KODAK CO     20626
# 5      11340     21776  0.152237            COLUMBIA ENERGY GROUP     20478
# 6      14509     14795  0.153350              SOUTHERN RAILWAY CO     22530
# 7      21127     25689  0.153990                        AXIA CORP     23051
# 8      22541     24109  0.154400                        G P U INC     20802
# 9      24272     25443  0.172480                 ASHLAND INC 2022     20222
# 10     12079     14736  0.185921              GENERAL MOTORS CORP     20799
# 11     14656     24969  0.194050                       SUNOCO INC     21686
# 12     10604     18278  0.206954            ATLANTIC RICHFIELD CO     20227
# 13     23448     23851  0.210032     VIRGINIA ELECTRIC & POWER CO     23211
# 14     12060     27959  0.213523              GENERAL ELECTRIC CO     20792
# 15     13821     22170  0.233745              PEOPLES ENERGY CORP     21382
# 16     21514     26470  0.247248                        SONAT INC     21632
# 17     10911     14904  0.261118               BUSH UNIVERSAL INC     22233
# 18     24491     27326  0.269761                 TOLEDO EDISON CO     23273
# 19     13311     24424  0.271961                      NABISCO INC     22426
# 20     23114     24096  0.272434              PROGRESS ENERGY INC     20397
# 21     10241     25232  0.272906                   PRIMERICA CORP     22177
# 22     23317     23720  0.294078                       ENRON CORP     20654
# 23     21397     25902  0.294662      CHAMPION INTERNATIONAL CORP     20427
# 24     23210     27158  0.296227      CLEVELAND ELECTRIC ILLUM CO     23199
# 25     11447     27799  0.316282            CONTINENTAL GROUP INC     22278
# 26     23931     24985  0.354337               X C E L ENERGY INC     21300
# 27     20132     25283  0.365875     PENNSYLVANIA GLASS SAND CORP     22976
# 28     22859     24045  0.367842                        D P L INC     20549
# 29     11703     24555  0.372897      DU PONT E I DE NEMOURS & CO     20606
# 30     24352     25953  0.379788               IOWA RESOURCES INC     21003
# 31     20730     27473  0.387710                        C B S INC     20354
# 32     21522     21768  0.396510                    FRUEHAUF CORP     23077
# 33     14605     22955  0.402081              STEWART WARNER CORP     22539
# 34     20095     24061  0.426405                  MURPHY G C & CO     22973
# 35     24010     25830  0.426462                 ENTERGY CORP NEW     21201
# 36     13522     24440  0.449221     NORFOLK & WESTERN RAILWAY CO     22446
# 37     12159     23405  0.468966                GRANBY MINING LTD     22332
# 38     11471     23085  0.476097                       CONOCO INC     22281
# 39     10321     11674  0.607435             AMERICAN MOTORS CORP     22184
# 40     19211     26585  0.609546              LILY TULIP CUP CORP     22904
# 41     23827     28193  0.671360              L G & E ENERGY CORP     21122
# 42     11391     25099  0.696361          CONSOLIDATED CIGAR CORP     22274
# 43     21645     27334  0.860100  AMERICAN EXPT ISBRANDTSEN LINES     23089
# 44     10591     24088  1.108165        ATLANTIC COAST LINE RR CO     22206
# 45     16344     21071  1.775101            THATCHER GLASS MFG CO     22682
# 46     14867     21485  3.060850               U V INDUSTRIES INC     22560
#
#    ticker_1 naics_1                        comnam_2  permco_2 ticker_2 naics_2
# 0       PET    <NA>          UNICOM CORP HOLDING CO     20486      UCM    <NA>
# 1        FE  221118        NATIONAL FUEL GAS CO N J     21255      NFG  221210
# 2       AYE  221121     DUQUESNE LIGHT HOLDINGS INC     20612      DQE  562211
# 3        ED  221118               C M S ENERGY CORP     20361      CMS  221118
# 4        EK  325992                     UNITED CORP     22809        U    <NA>
# 5        CG    <NA>                     EXELON CORP     21396      EXC  221118
# 6        SR    <NA>                       TIMKEN CO     21758      TKR  332991
# 7        AX    <NA>                   DAN RIVER INC     23352      DML    <NA>
# 8       GPU    <NA>  AMERICAN ELECTRIC POWER CO INC     20077      AEP  221118
# 9       ASH  424690                PUGET ENERGY INC     21461      PSD  221111
# 10       GM  336111                      TEXACO INC     21734       TX    <NA>
# 11      SUN  324110                     AVISTA CORP     21890      AVA  221118
# 12      ARC    <NA>                     INTERCO INC     20987      ISS    <NA>
# 13      VEL    <NA>       CENTRAL & SOUTH WEST CORP     20414      CSR    <NA>
# 14       GE  333611            DUKE ENERGY CORP NEW     20608      DUK  221118
# 15      PGL  221210                      KOPPERS CO     23123      KOP    <NA>
# 16      SNT    <NA>                    ENERGEN CORP     20649      EGN  211120
# 17      BSH    <NA>       UNION PACIFIC RAILROAD CO     22563       UP    <NA>
# 18      TED    <NA>                   TORRINGTON CO     23470      TOR    <NA>
# 19      NAB    <NA>           UTAH POWER & LIGHT CO     23270      UTP    <NA>
# 20      PGN  221122                ENERGY EAST CORP     21278      EAS  221121
# 21       PA    <NA>                   ONEOK INC NEW     21332      OKE  221210
# 22      ENE    <NA>                   ILLINOVA CORP     20967      ILN    <NA>
# 23      CHA    <NA>    GENERAL STEEL INDUSTRIES INC     23370      GSI    <NA>
# 24      CVX    <NA>                CENTRAL SOYA INC     23456      CSY    <NA>
# 25      CCC    <NA>                    AMERCON CORP     23500      AEM    <NA>
# 26      XEL  221118                     AMEREN CORP     21808      AEE  221118
# 27      PGS    <NA>  SOUTHWESTERN PUBLIC SERVICE CO     21646      SPS    <NA>
# 28      DPL  221111          I U INTERNATIONAL CORP     23253       IU    <NA>
# 29       DD  325320            AMALGAMATED SUGAR CO     23278      AGM    <NA>
# 30      IOR    <NA>                      DOVER CORP     20596      DOV  333415
# 31      CBS    <NA>                       SINGER CO     23479      SMF    <NA>
# 32      FTR    <NA>                       GULF CORP     23101       GO    <NA>
# 33      STX    <NA>  COLUMBUS & SOUTHN OHIO ELEC CO     23180      COC    <NA>
# 34      MPH    <NA>                 UNITED GAS CORP     23255      UGC    <NA>
# 35      ETR  221118            BUCKEYE PIPE LINE CO     23364      BKP    <NA>
# 36      NFK    <NA>               O G E ENERGY CORP     21328      OGE  221118
# 37       GB    <NA>        GULF STATES UTILITIES CO     20862      GSU    <NA>
# 38      CLL    <NA>                  SCANA CORP NEW     21570      SCG  221121
# 39      AMO    <NA>                 D T E ENERGY CO     20574      DTE  221118
# 40      LIL    <NA>            I E S INDUSTRIES INC     20956      IES    <NA>
# 41      LGE    <NA>     NATIONAL STARCH & CHEM CORP     23526      NSC    <NA>
# 42      CDR    <NA>       INTEGRYS ENERGY GROUP INC     21932      TEG  221210
# 43      AEX    <NA>              CARLISLE COMPANIES     20392      CSL  324122
# 44       AX    <NA>                     ARISTAR INC     23256      ARR    <NA>
# 45      TMC    <NA>   UNITED STATES PLAYING CARD CO     23046      USP    <NA>
# 46       UV    <NA>                       N W A INC     23073      NWA    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 6 for cluster ID: 13 with 12 stocks
#    permno_1  permno_2       ssd               comnam_1  permco_1 ticker_1  \
# 0     22322     28249  0.328034       BELL & HOWELL CO     23135      BHW
# 1     26921     27238  0.380110       UNIDYNAMICS CORP     23437       UD
# 2     12167     27289  0.699069         GRAND UNION CO     22333      GUX
# 3     15579     23253  0.745377  TEXAS INSTRUMENTS INC     21737      TXN
# 4     10874     11105  1.336271         BRUNSWICK CORP     20344       BC
# 5     21282     27182  2.084633   CHRIS CRAFT INDS INC     20444      CCN
#
#   naics_1                    comnam_2  permco_2 ticker_2 naics_2
# 0    <NA>            HALLICRAFTERS CO     23530      HLF    <NA>
# 1    <NA>                    VENDO CO     23463      VEN    <NA>
# 2    <NA>                 BORMANS INC     23466      BRF    <NA>
# 3  334413     GENERAL INSTRUMENT CORP     20797      GRL    <NA>
# 4  333618           CERTAIN TEED CORP     22248      CRT    <NA>
# 5    <NA>  TRANSITRON ELECTRONIC CORP      5546     TREL    <NA>
# Computing pairwise SSD
# Matching into pairs
# Loading library list...
# Done
# Total pairs formed: 13 for cluster ID: 14 with 27 stocks
#     permno_1  permno_2       ssd                         comnam_1  permco_1  \
# 0      23624     25160  0.331520           ROBERTSHAW CONTROLS CO     23222
# 1      16088     17777  0.331600      WHITE CONSOLIDATED INDS INC     22657
# 2      12095     27668  0.367281              GENERAL SIGNAL CORP     20804
# 3      13792     15317  0.535787                  PENN CENTRAL CO     22472
# 4      15755     23202  0.576721              SHATTUCK FRANK G CO     22630
# 5      15464     19430  0.578327                 WORTHINGTON CORP     22608
# 6      11543     37129  0.594654                        CUDAHY CO     22287
# 7      22402     27633  0.640949  CHICAGO MILWAUKEE ST PAUL & PAC     23142
# 8      14760     16336  0.688103                    TEXASGULF INC     22552
# 9      22728     26016  0.708777                LOWENSTEIN M CORP     23162
# 10     26665     27094  1.379798                     THIOKOL CORP     23421
# 11     14701     20140  1.926179                TELAUTOGRAPH CORP     22548
# 12     10807     17515  2.872452                    BRIGGS MFG CO     22226
#
#    ticker_1 naics_1                     comnam_2  permco_2 ticker_2 naics_2
# 0       ROF    <NA>  GREAT NORTHERN NEKOOSA CORP     20847      GNN    <NA>
# 1       WSW    <NA>        MORRELL JOHN & CO INC     22803      MOL    <NA>
# 2       GSX    <NA>        PFAUDLER PERMUTIT INC     23493      PPM    <NA>
# 3        PC    <NA>       WESTERN MARYLAND RY CO      4955     WMRY    <NA>
# 4       FHK    <NA>      VICTOR COMPTOMETER CORP     23198      VCR    <NA>
# 5       WTH    <NA>       RICHARDSON MERRELL INC     22921      RXM    <NA>
# 6       CUD    <NA>         T S C INDUSTRIES INC     24206      TSC    <NA>
# 7        ST    <NA>            RYDER SYSTEMS INC     21541        R  532120
# 8        TG    <NA>                 QUESTOR CORP     22681       IQ    <NA>
# 9       LST    <NA>                   SCHICK INC     23376      SHK    <NA>
# 10      THI    <NA>             COLLINS RADIO CO     23451      CRI    <NA>
# 11      TEL    <NA>            GENERAL TIME CORP     22977      GLI    <NA>
# 12       BG    <NA>         CURTIS PUBLISHING CO     22785      CPC    <NA>
# Computing pairwise SSD
# Matching into pairs
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)
#    3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
#     442 The connection is instrumented such that when its
#    (...)
#     445
#     446 """
# --> 447 return _ConnectionFairy._checkout(self)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#
# File c:\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     174 try:
# --> 175     return self._create_connection()
#     176 except:
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:388, in Pool._create_connection(self)
#     386 """Called by subclasses to create a new ConnectionRecord."""
# --> 388 return _ConnectionRecord(self)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:899, in _ConnectionRecord.__connect(self)
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:895, in _ConnectionRecord.__connect(self)
#     894 self.starttime = time.time()
# --> 895 self.dbapi_connection = connection = pool._invoke_creator(self)
#     896 pool.logger.debug("Created new connection %r", connection)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\create.py:661, in create_engine.<locals>.connect(connection_record)
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\default.py:629, in DefaultDialect.connect(self, *cargs, **cparams)
#     627 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     628     # inherits the docstring from interfaces.Dialect.connect
# --> 629     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Python311\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "wrds-pgdata.wharton.upenn.edu" (165.123.60.118), port 9737 failed: FATAL:  too many connections for role "sohrac"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[20], line 18
#      16 matched_pairs = pair_matching(ssd_df, crsp_data, max_pairs=10000)
#      17 matched_pairs = matched_pairs.sort_values('ssd').reset_index(drop=True)
# ---> 18 matched_pairs_named = get_stock(matched_pairs)
#      20 print(f"Total pairs formed: {len(matched_pairs_named)} for cluster ID: {cluster_id} with {len(stocks)} stocks")
#      21 print(matched_pairs_named)
#
# File c:\Users\Rachael Soh\QF600_AssetPricing\qf600-pair-trading\pairs_formation.py:178, in get_stock(df)
#     177 def get_stock(df) -> pd.DataFrame:
# --> 178   db = wrds.Connection(wrds_username='sohrac')
#     180   permnos = set(df['permno_1'].unique()).union(df['permno_2'].unique())
#     181   comnames = db.raw_sql(
#     182     f"""
#     183     SELECT distinct on (permno) comnam, permno, permco, ticker, naics
#    (...)
#     187     """
#     188   )
#
# File c:\Python311\Lib\site-packages\wrds\sql.py:76, in Connection.__init__(self, autoconnect, verbose, **kwargs)
#      73 self._connect_args = kwargs.get("wrds_connect_args", WRDS_CONNECT_ARGS)
#      75 if autoconnect:
# ---> 76     self.connect()
#      77     self.load_library_list()
#
# File c:\Python311\Lib\site-packages\wrds\sql.py:117, in Connection.connect(self)
#     115 self._username, self._password = self.__get_user_credentials()
#     116 # Last attempt, raise error if Exception encountered
# --> 117 self.__make_sa_engine_conn(raise_err=True)
#     119 if self.engine is None:
#     120     print(f"Failed to connect {self._username}@{self._hostname}")
#
# File c:\Python311\Lib\site-packages\wrds\sql.py:100, in Connection.__make_sa_engine_conn(self, raise_err)
#      98 self.engine = None
#      99 if raise_err:
# --> 100     raise err
#
# File c:\Python311\Lib\site-packages\wrds\sql.py:94, in Connection.__make_sa_engine_conn(self, raise_err)
#      88 try:
#      89     self.engine = sa.create_engine(
#      90         pguri,
#      91         isolation_level="AUTOCOMMIT",
#      92         connect_args=self._connect_args,
#      93     )
# ---> 94     self.connection = self.engine.connect()
#      95 except Exception as err:
#      96     if self._verbose:
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3277, in Engine.connect(self)
#    3254 def connect(self) -> Connection:
#    3255     """Return a new :class:`_engine.Connection` object.
#    3256
#    3257     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3274
#    3275     """
# -> 3277     return self._connection_cls(self)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
# --> 145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#     148         raise
#     149 else:
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\base.py:2440, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2438 elif should_wrap:
#    2439     assert sqlalchemy_exception is not None
# -> 2440     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2441 else:
#    2442     assert exc_info[1] is not None
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     141 if connection is None:
#     142     try:
# --> 143         self._dbapi_connection = engine.raw_connection()
#     144     except dialect.loaded_dbapi.Error as err:
#     145         Connection._handle_dbapi_exception_noconnection(
#     146             err, dialect, engine
#     147         )
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3279 def raw_connection(self) -> PoolProxiedConnection:
#    3280     """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282     The returned object is a proxied version of the DBAPI
#    (...)
#    3299
#    3300     """
# -> 3301     return self.pool.connect()
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     439 def connect(self) -> PoolProxiedConnection:
#     440     """Return a DBAPI connection from the pool.
#     441
#     442     The connection is instrumented such that when its
#    (...)
#     445
#     446     """
# --> 447     return _ConnectionFairy._checkout(self)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)
#    1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:711, in _ConnectionRecord.checkout(cls, pool)
#     709     rec = cast(_ConnectionRecord, pool._do_get())
#     710 else:
# --> 711     rec = pool._do_get()
#     713 try:
#     714     dbapi_connection = rec.get_connection()
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175     return self._create_connection()
#     176 except:
# --> 177     with util.safe_reraise():
#     178         self._dec_overflow()
#     179     raise
#
# File c:\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\impl.py:175, in QueuePool._do_get(self)
#     173 if self._inc_overflow():
#     174     try:
# --> 175         return self._create_connection()
#     176     except:
#     177         with util.safe_reraise():
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:388, in Pool._create_connection(self)
#     385 def _create_connection(self) -> ConnectionPoolEntry:
#     386     """Called by subclasses to create a new ConnectionRecord."""
# --> 388     return _ConnectionRecord(self)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:673, in _ConnectionRecord.__init__(self, pool, connect)
#     671 self.__pool = pool
#     672 if connect:
# --> 673     self.__connect()
#     674 self.finalize_callback = deque()
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:899, in _ConnectionRecord.__connect(self)
#     897     self.fresh = True
#     898 except BaseException as e:
# --> 899     with util.safe_reraise():
#     900         pool.logger.debug("Error on connect(): %s", e)
#     901 else:
#     902     # in SQLAlchemy 1.4 the first_connect event is not used by
#     903     # the engine, so this will usually not be set
#
# File c:\Python311\Lib\site-packages\sqlalchemy\util\langhelpers.py:224, in safe_reraise.__exit__(self, type_, value, traceback)
#     222     assert exc_value is not None
#     223     self._exc_info = None  # remove potential circular references
# --> 224     raise exc_value.with_traceback(exc_tb)
#     225 else:
#     226     self._exc_info = None  # remove potential circular references
#
# File c:\Python311\Lib\site-packages\sqlalchemy\pool\base.py:895, in _ConnectionRecord.__connect(self)
#     893 try:
#     894     self.starttime = time.time()
# --> 895     self.dbapi_connection = connection = pool._invoke_creator(self)
#     896     pool.logger.debug("Created new connection %r", connection)
#     897     self.fresh = True
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\create.py:661, in create_engine.<locals>.connect(connection_record)
#     658         if connection is not None:
#     659             return connection
# --> 661 return dialect.connect(*cargs, **cparams)
#
# File c:\Python311\Lib\site-packages\sqlalchemy\engine\default.py:629, in DefaultDialect.connect(self, *cargs, **cparams)
#     627 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     628     # inherits the docstring from interfaces.Dialect.connect
# --> 629     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File c:\Python311\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "wrds-pgdata.wharton.upenn.edu" (165.123.60.118), port 9737 failed: FATAL:  too many connections for role "sohrac"
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
